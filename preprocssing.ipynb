# %%
###########################
# Pre-processing the data #
###########################


import pandas as pd
import numpy as np

files = ['miller_idle', 'sam_wild', 'layton_idle', 'miller_wild', 'val_idle', 'layton_wild', 'sam_idle', 'val_wild']  #filename in the folder

# %%
def preprocessing(filename):

    d = pd.read_csv(filename)   #read the CSV file
    # print (d)
    d_drop = d.drop("Sensor type", axis=1)   #drop the first column -- sensor type
    #print (d_drop)
    d_matrix = d_drop.as_matrix()   # Using pandas again to convert the revised table into a matrix
    #print (d_matrix)

    n_array = np.array(d_matrix) # now we use numpy to convert the pandas matrix into a Numpy array
    #print (n_array)
   
    #delete the last row if the revised row number is odd, otherwise cut last too rows
    n_array = n_array[:-1] if len(n_array) % 2 == 1 else n_array[:-2] 
    #print (n_conc)

    #Concatenate the EMG and Accerlaration rows for (nearly) the same time moments
    n_conc = np.concatenate((n_array[::2], n_array[1::2]), axis = 1)    
    #print (n_conc)

    n_del = np.delete(n_conc, [1, 2], axis = 1) #delete the second and third columns of each list in the matrix
    print (n_del)
    return np.savetxt(filename + 'processed', n_del, delimiter=',', fmt = '%f')  #save the output into a file

# %%
for f in files:
    preprocessing(f)
# Out:
# [[  4.07200000e+03   1.04450000e+01  -3.28000000e-01   2.26500000e-01
#    -9.49000000e-01   1.24240000e+01]
#  [  4.04300000e+03   2.68400000e+01  -3.16000000e-01   2.14800000e-01
#    -9.37000000e-01   2.78840000e+01]
#  [  4.04200000e+03   3.75730000e+01  -3.35000000e-01   2.26500000e-01
#    -9.45000000e-01   3.85940000e+01]
#  ...,
#  [  4.04100000e+03   2.75940000e+04  -3.08000000e-01   2.50000000e-01
#    -9.33000000e-01   2.75960000e+04]
#  [  4.05700000e+03   2.76050000e+04  -3.20000000e-01   2.57800000e-01
#    -9.84000000e-01   2.76060000e+04]
#  [  4.01600000e+03   2.76150000e+04  -3.24000000e-01   2.61700000e-01
#    -9.41000000e-01   2.76170000e+04]]
# [[  3.32300000e+03   1.20290000e+01  -9.70000000e-02  -8.50000000e-02
#     9.37500000e-01   1.54460000e+01]
#  [  3.60600000e+03   2.57270000e+01  -1.25000000e-01  -1.01000000e-01
#     9.33500000e-01   2.74040000e+01]
#  [  3.87600000e+03   3.82600000e+01  -1.21000000e-01  -7.80000000e-02
#     9.06200000e-01   3.99180000e+01]
#  ...,
#  [  7.75800000e+03   2.36587000e+05   9.76500000e-01   2.14800000e-01
#    -4.57000000e-01   2.36588000e+05]
#  [  7.65500000e+03   2.36598000e+05   1.00000000e+00   1.79600000e-01
#    -5.15000000e-01   2.36599000e+05]
#  [  7.63100000e+03   2.36608000e+05   1.02730000e+00   1.87500000e-01
#    -5.74000000e-01   2.36609000e+05]]
# [[  6.43200000e+03   1.04120000e+01  -1.83000000e-01   3.12500000e-01
#    -9.53000000e-01   1.23440000e+01]
#  [  6.53700000e+03   2.17880000e+01  -1.83000000e-01   2.92900000e-01
#    -9.60000000e-01   2.29780000e+01]
#  [  6.63100000e+03   3.27790000e+01  -1.79000000e-01   3.12500000e-01
#    -9.64000000e-01   3.37950000e+01]
#  ...,
#  [  6.81900000e+03   2.73960000e+04  -1.56000000e-01   3.12500000e-01
#    -9.53000000e-01   2.73970000e+04]
#  [  6.72500000e+03   2.74060000e+04  -1.56000000e-01   3.20300000e-01
#    -9.60000000e-01   2.74080000e+04]
#  [  6.79400000e+03   2.74170000e+04  -1.56000000e-01   3.24200000e-01
#    -9.68000000e-01   2.74180000e+04]]
# [[  4.08800000e+03   1.05310000e+01  -3.35000000e-01   2.73400000e-01
#    -9.49000000e-01   1.24940000e+01]
#  [  4.13300000e+03   2.20360000e+01  -3.43000000e-01   2.73400000e-01
